# %%
a=7

# %%
if a>6:
    print('hi')
    if a>8:
        print('hello')
    print('abc')
print('cde')
# Out:
# hi
# abc
# cde

# %%
if a>6:
    print('hii')
else:
    print('bye')
# Out:
# hii

# %%
mark=70

# %%
if mark>90:
    print('A')
elif mark>80:
    print('B')
elif mark>70:
    print('C')
else:
    print('Failed')
# Out:
# Failed

# %%
a='hello world'
a[0]
# Out:
# 'h'

# %%
a=[4,5,6,7,8]
b=0
for i in a:
    b=b+1

# %%
b
# Out:
# 5

# %%
len(b)
# Out:
# 5

# %%
a='hello world'
v=['a','e','i','o','u','A','E','I','O']
b=0
for i in a:
    if i in v:
        b=b+1

# %%
a=10
while a>5:
    

    print('hi')
    a=a-1
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
a=10
while True:
    print('hi')
    a=a-1
    if a==5:
        break
    if a == 8:
        continue
    print(a)
    print('hio')
# Out:
# hi
# hio
# hi
# hio
# hi
# hio
# hi
# hio
# hi

# %%
a=10
while a>6:
    a=a-1
    if a == 8:
        continue
    print(a)
    print('hio')
# Out:
# 9
# hio
# 7
# hio
# 6
# hio

# %%
if a>6:
    print('hi')
else:
    print('bye')
# Out:
# bye

# %%
print('hi')if a>6 else print('bye')
# Out:
# bye

# %% [markdown]
# value_if_true if condition else value_if_false

# %% [markdown]
# value1 if condition1 else
# value2 if condition2 else value3
