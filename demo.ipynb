# %%
a=10

# %%
a_2=5

# %%
a_2
# Out:
# 5

# %%
_abc=5

# %%
a
# Out:
# 10

# %%
b=10

# %%
c=10
c=c+1

# %%
id(a)
# Out:
# 140718376568008

# %%
id(b)
# Out:
# 140718376568008

# %%
id(c)
# Out:
# 140718376568040

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
b=None
