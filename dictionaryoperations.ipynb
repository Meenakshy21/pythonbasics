# %%
d={'name':'abc','age':22}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
d.values()
# Out:
# dict_values(['abc', 22])

# %%
d.items()
# Out:
# dict_items([('name', 'abc'), ('age', 22)])

# %%
for i in d:
    print(d[i])
# Out:
# abc
# 22

# %%
d["name"]
# Out:
# 'abc'

# %%
for i in d.keys():
    print(i)
# Out:
# name
# age
