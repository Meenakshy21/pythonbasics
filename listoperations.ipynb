# %%
a=[1,2,3,4,5]

# %%
a[0]
# Out:
# 1

# %%
a[0:5:2]
# Out:
# [1, 3, 5]

# %% [markdown]
# ## List Operations
#
# ### Creation
# - Creating empty lists
# - Creating lists with elements
# - Creating lists from other collections
#
# ### Accessing
# - Accessing elements by index
# - Accessing elements from the end
# - Accessing sublists (slicing)
#
# ### Updating
# - Modifying elements
# - Replacing multiple elements
#
# ### Adding Elements
# - Adding elements at the end
# - Inserting elements at a specific position
# - Adding multiple elements
#
# ### Removing Elements
# - Removing elements by value
# - Removing elements by index
# - Removing the last element
# - Clearing all elements
#
# ### Searching & Checking
# - Checking element existence
# - Finding element position
# - Counting occurrences
#
# ### Ordering
# - Sorting elements
# - Reversing the list
#
# ### Combining
# - Concatenating lists
# - Repeating lists
#
# ### Copying
# - Shallow copying
# - Independent copying
#
# ### Aggregation
# - Finding length
# - Finding minimum and maximum
# - Calculating sum
#
# ### Iteration
# - Traversing elements
# - Traversing with index
#
# ### Nested Lists
# - Creating nested lists
# - Accessing nested elements
# - Modifying nested elements

# %%
b = [1, 2, 3, 4]
b.append(50) 
c=[]
c.append(50)

# %%
b
# Out:
# [1, 50, 2, 3, 4, 50, 50]

# %%
b.insert(1, 50)

# %%
b.extend(c)

# %%
b.remove(50)

# %%
b.pop()
# Out:
# 50

# %%
c=b.pop()

# %%
c
# Out:
# 50

# %%
#b.remove(15)                    # remove by value
#b.pop(2)                        # remove by index
#b.pop()                         # remove last element
b.clear()

# %%
print(b.index(50))
# Out:
# 1

# %%
print(b.count(50))
# Out:
# 3

# %%
print(20 in b)
# Out:
# False

# %%
print(20 not in b)
# Out:
# True

# %%
b.sort()                        # sort list
b.reverse()
